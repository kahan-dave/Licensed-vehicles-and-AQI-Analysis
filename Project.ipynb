# %% [markdown]
# # Important Imports

# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
import sys
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# %matplotlib inline

# %% [markdown]
# # Data Cleaning

# %%
df = pd.read_csv("Data/city_day.csv")
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %%
city = ["Ahmedabad", "Delhi"]

ad = df.loc[df['City'].isin(city)]

# %%
ad.isna().sum()
# Out:
# City             0
# Date             0
# PM2.5          630
# PM10          1679
# NO             611
# NO2            610
# NOx            594
# NH3           2018
# CO             609
# SO2            750
# O3             769
# Benzene        483
# Toluene        483
# Xylene        1265
# AQI            685
# AQI_Bucket     685
# dtype: int64

# %%
 amd = ad.loc[df['City'] == "Ahmedabad"]

# %%
amd
# Out:
#            City        Date  PM2.5    PM10     NO    NO2    NOx  NH3     CO  \
# 0     Ahmedabad  2015-01-01    NaN     NaN   0.92  18.22  17.15  NaN   0.92
# 1     Ahmedabad  2015-01-02    NaN     NaN   0.97  15.69  16.46  NaN   0.97
# 2     Ahmedabad  2015-01-03    NaN     NaN  17.40  19.30  29.70  NaN  17.40
# 3     Ahmedabad  2015-01-04    NaN     NaN   1.70  18.48  17.97  NaN   1.70
# 4     Ahmedabad  2015-01-05    NaN     NaN  22.10  21.42  37.76  NaN  22.10
# ...         ...         ...    ...     ...    ...    ...    ...  ...    ...
# 2004  Ahmedabad  2020-06-27  62.12  118.67   9.18  56.35  19.86  NaN   0.49
# 2005  Ahmedabad  2020-06-28  31.57     NaN   6.37  23.99  16.40  NaN   0.52
# 2006  Ahmedabad  2020-06-29  29.75  127.98   9.06  25.15  18.92  NaN   0.67
# 2007  Ahmedabad  2020-06-30  40.02  121.10   7.09  58.92  33.41  NaN   0.73
# 2008  Ahmedabad  2020-07-01  37.63     NaN   4.42  35.04  20.17  NaN   0.28
#
#         SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# 0     27.64  133.36     0.00     0.02    0.00    NaN           NaN
# 1     24.55   34.06     3.68     5.50    3.77    NaN           NaN
# 2     29.07   30.70     6.80    16.40    2.25    NaN           NaN
# 3     18.59   36.08     4.43    10.14    1.00    NaN           NaN
# 4     39.33   39.31     7.01    18.89    2.78    NaN           NaN
# ...     ...     ...      ...      ...     ...    ...           ...
# 2004  12.44   68.05     1.32    37.76    1.62   92.0  Satisfactory
# 2005  11.01   26.34     1.37    49.58    1.34   82.0  Satisfactory
# 2006  12.10   34.99     1.39    60.21    0.79   74.0  Satisfactory
# 2007  16.39   41.64     1.21    44.10    1.35   98.0  Satisfactory
# 2008  14.40    9.69     1.73    47.05    1.87  119.0      Moderate
#
# [2009 rows x 16 columns]

# %%
amd.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  2009.000000  2009.000000  2009.000000  2009.000000  2009.000000
# mean     67.854497   114.584029    22.428021    59.025496    47.366898
# std      32.738650    20.559483    17.892419    39.481286    28.198404
# min       3.040000    11.500000     0.060000     0.080000     0.000000
# 25%      46.910000   114.584029    10.380000    30.230000    27.840000
# 50%      67.854497   114.584029    22.428021    59.025496    47.366898
# 75%      73.070000   114.584029    23.750000    66.430000    51.030000
# max     381.690000   586.270000   175.810000   292.020000   246.030000
#
#           NH3           CO          SO2           O3      Benzene  \
# count  2009.0  2009.000000  2009.000000  2009.000000  2009.000000
# mean      0.0    22.193407    55.253733    39.155408     5.413807
# std       0.0    18.064252    32.837277    18.331331     6.893336
# min       0.0     0.060000     0.520000     0.380000     0.000000
# 25%       0.0    10.330000    34.400000    32.100000     1.820000
# 50%       0.0    22.193407    55.253733    39.155408     4.450000
# 75%       0.0    23.750000    60.680000    45.650000     5.413807
# max       0.0   175.810000   186.080000   162.430000   115.140000
#
#            Toluene       Xylene          AQI
# count  2009.000000  2009.000000  2009.000000
# mean     27.740524     4.248341   452.122939
# std      25.521137     6.527949   253.986830
# min       0.000000     0.000000    48.000000
# 25%      10.250000     0.660000   303.000000
# 50%      27.740524     3.590000   452.122939
# 75%      32.330000     4.248341   465.000000
# max     371.650000   109.230000  2049.000000

# %%
ameans = {"PM2.5": 67.854497,
         "PM10": 114.584029,
         "NO": 22.428021, 
         "NO2": 59.025496,
         "NOx": 47.366898,
         "NH3": 0,
         "CO": 22.193407,
         "SO2": 55.253733,
         "O3": 39.155408,
         "Benzene": 5.413807,
         "Toluene": 27.740524,
         "Xylene": 4.248341,
         "AQI": 452.122939}

# %%
amd = amd.fillna(ameans)

# %%
dhl = ad.loc[df['City'] == "Delhi"]
dhl
# Out:
#         City        Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 10229  Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 10230  Delhi  2015-01-02  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 10231  Delhi  2015-01-03   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 10232  Delhi  2015-01-04  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 10233  Delhi  2015-01-05  146.60  219.13  14.01  34.92   38.25  122.88   9.20
# ...      ...         ...     ...     ...    ...    ...     ...     ...    ...
# 12233  Delhi  2020-06-27   39.80  155.94  10.88  21.46   22.47   31.43   0.87
# 12234  Delhi  2020-06-28   59.52  308.65  12.67  21.60   23.86   29.27   0.94
# 12235  Delhi  2020-06-29   44.86  184.12  10.50  21.57   21.94   27.97   0.88
# 12236  Delhi  2020-06-30   39.80   91.98   5.99  17.96   15.44   28.48   0.84
# 12237  Delhi  2020-07-01   54.01  128.66   6.33  21.05   16.81   29.06   0.97
#
#          SO2     O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 10229   9.25  41.68    14.36    24.86    9.84  472.0     Severe
# 10230   6.65  29.97    10.55    20.09    4.29  454.0     Severe
# 10231   2.65  19.71     3.91    10.23    1.99  143.0   Moderate
# 10232   4.63  25.36     4.26     9.71    3.34  319.0  Very Poor
# 10233   3.33  23.20     2.80     6.21    2.96  325.0  Very Poor
# ...      ...    ...      ...      ...     ...    ...        ...
# 12233  10.38  18.88     1.69    19.99    0.43  112.0   Moderate
# 12234  10.70  18.05     1.71    25.13    1.74  196.0   Moderate
# 12235  11.58  26.61     2.13    23.80    1.13  233.0       Poor
# 12236  10.51  37.29     1.57    16.37    0.49  114.0   Moderate
# 12237  11.15  29.73     2.03    23.57    0.65  101.0   Moderate
#
# [2009 rows x 16 columns]

# %%
dhl.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  2007.000000  1932.000000  2007.000000  2007.000000  2009.000000
# mean    117.196153   232.809229    38.985595    50.785182    58.567023
# std      82.912945   121.873025    33.389456    22.696721    37.690350
# min      10.240000    18.590000     3.570000    10.630000     0.000000
# 25%      57.095000   137.040000    15.895000    33.895000    31.150000
# 50%      94.620000   216.730000    27.200000    47.150000    52.750000
# 75%     153.030000   311.667500    50.790000    63.570000    75.360000
# max     685.360000   796.880000   221.030000   162.500000   254.800000
#
#                NH3           CO          SO2          O3      Benzene  \
# count  2000.000000  2009.000000  1899.000000  1925.00000  2009.000000
# mean     41.997150     1.976053    15.901253    51.32361     3.544480
# std      17.301221     2.560253     7.966770    26.06234     2.431232
# min       6.780000     0.000000     2.340000     6.94000     0.000000
# 25%      31.157500     0.910000    10.335000    33.71000     1.870000
# 50%      38.040000     1.240000    14.450000    44.44000     2.960000
# 75%      48.792500     1.870000    19.700000    60.84000     4.680000
# max     166.700000    30.440000    71.560000   257.73000    20.640000
#
#            Toluene       Xylene          AQI
# count  2009.000000  1228.000000  1999.000000
# mean     17.185042     1.438339   259.487744
# std      15.291597     2.377762   119.537333
# min       0.000000     0.000000    29.000000
# 25%       6.650000     0.110000   161.500000
# 50%      12.750000     0.650000   257.000000
# 75%      23.200000     1.970000   345.500000
# max     103.000000    23.300000   716.000000

# %%
dmeans = {"PM2.5": 117.196153,
         "PM10": 232.809229,
         "NO": 38.985595, 
         "NO2": 50.785182,
         "NOx": 58.567023,
         "NH3": 41.997150,
         "CO": 1.976053,
         "SO2": 15.901253,
         "O3": 51.32361,
         "Benzene": 3.544480,
         "Toluene": 17.185042,
         "Xylene": 1.438339,
         "AQI": 259.487744}

# %%
dhl = dhl.fillna(dmeans)

# %%
fad = pd.concat([amd, dhl])

# %%
fad
# Out:
#             City        Date      PM2.5        PM10     NO    NO2    NOx  \
# 0      Ahmedabad  2015-01-01  67.854497  114.584029   0.92  18.22  17.15
# 1      Ahmedabad  2015-01-02  67.854497  114.584029   0.97  15.69  16.46
# 2      Ahmedabad  2015-01-03  67.854497  114.584029  17.40  19.30  29.70
# 3      Ahmedabad  2015-01-04  67.854497  114.584029   1.70  18.48  17.97
# 4      Ahmedabad  2015-01-05  67.854497  114.584029  22.10  21.42  37.76
# ...          ...         ...        ...         ...    ...    ...    ...
# 12233      Delhi  2020-06-27  39.800000  155.940000  10.88  21.46  22.47
# 12234      Delhi  2020-06-28  59.520000  308.650000  12.67  21.60  23.86
# 12235      Delhi  2020-06-29  44.860000  184.120000  10.50  21.57  21.94
# 12236      Delhi  2020-06-30  39.800000   91.980000   5.99  17.96  15.44
# 12237      Delhi  2020-07-01  54.010000  128.660000   6.33  21.05  16.81
#
#          NH3     CO    SO2      O3  Benzene  Toluene  Xylene         AQI  \
# 0       0.00   0.92  27.64  133.36     0.00     0.02    0.00  452.122939
# 1       0.00   0.97  24.55   34.06     3.68     5.50    3.77  452.122939
# 2       0.00  17.40  29.07   30.70     6.80    16.40    2.25  452.122939
# 3       0.00   1.70  18.59   36.08     4.43    10.14    1.00  452.122939
# 4       0.00  22.10  39.33   39.31     7.01    18.89    2.78  452.122939
# ...      ...    ...    ...     ...      ...      ...     ...         ...
# 12233  31.43   0.87  10.38   18.88     1.69    19.99    0.43  112.000000
# 12234  29.27   0.94  10.70   18.05     1.71    25.13    1.74  196.000000
# 12235  27.97   0.88  11.58   26.61     2.13    23.80    1.13  233.000000
# 12236  28.48   0.84  10.51   37.29     1.57    16.37    0.49  114.000000
# 12237  29.06   0.97  11.15   29.73     2.03    23.57    0.65  101.000000
#
#       AQI_Bucket
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 12233   Moderate
# 12234   Moderate
# 12235       Poor
# 12236   Moderate
# 12237   Moderate
#
# [4018 rows x 16 columns]

# %%
#fad.to_csv('Data/FAD.csv')

# %%
dffad = pd.read_csv("Data/FAD.csv", parse_dates=['Date'])

# %%
dffad
# Out:
#            City       Date      PM2.5        PM10     NO    NO2    NOx    NH3  \
# 0     Ahmedabad 2015-01-01  67.854497  114.584029   0.92  18.22  17.15   0.00
# 1     Ahmedabad 2015-01-02  67.854497  114.584029   0.97  15.69  16.46   0.00
# 2     Ahmedabad 2015-01-03  67.854497  114.584029  17.40  19.30  29.70   0.00
# 3     Ahmedabad 2015-01-04  67.854497  114.584029   1.70  18.48  17.97   0.00
# 4     Ahmedabad 2015-01-05  67.854497  114.584029  22.10  21.42  37.76   0.00
# ...         ...        ...        ...         ...    ...    ...    ...    ...
# 4013      Delhi 2020-06-27  39.800000  155.940000  10.88  21.46  22.47  31.43
# 4014      Delhi 2020-06-28  59.520000  308.650000  12.67  21.60  23.86  29.27
# 4015      Delhi 2020-06-29  44.860000  184.120000  10.50  21.57  21.94  27.97
# 4016      Delhi 2020-06-30  39.800000   91.980000   5.99  17.96  15.44  28.48
# 4017      Delhi 2020-07-01  54.010000  128.660000   6.33  21.05  16.81  29.06
#
#          CO    SO2      O3  Benzene  Toluene  Xylene         AQI AQI_Bucket
# 0      0.92  27.64  133.36     0.00     0.02    0.00  452.122939  Very Poor
# 1      0.97  24.55   34.06     3.68     5.50    3.77  452.122939  Very Poor
# 2     17.40  29.07   30.70     6.80    16.40    2.25  452.122939  Very Poor
# 3      1.70  18.59   36.08     4.43    10.14    1.00  452.122939  Very Poor
# 4     22.10  39.33   39.31     7.01    18.89    2.78  452.122939  Very Poor
# ...     ...    ...     ...      ...      ...     ...         ...        ...
# 4013   0.87  10.38   18.88     1.69    19.99    0.43  112.000000   Moderate
# 4014   0.94  10.70   18.05     1.71    25.13    1.74  196.000000   Moderate
# 4015   0.88  11.58   26.61     2.13    23.80    1.13  233.000000       Poor
# 4016   0.84  10.51   37.29     1.57    16.37    0.49  114.000000   Moderate
# 4017   0.97  11.15   29.73     2.03    23.57    0.65  101.000000   Moderate
#
# [4018 rows x 16 columns]

# %%
sorting = ["City", "Date"]
dffad.sort_values(by=sorting, inplace=True)
sortDffad = dffad
sortDffad = sortDffad.groupby(pd.Grouper(key='Date', axis=0, freq='Y')).mean()

# %%
sortDffad
# Out:
#                  PM2.5        PM10         NO        NO2        NOx  \
# Date
# 2015-12-31   96.957722  172.314459  23.977015  38.897006  58.671256
# 2016-12-31  102.264513  186.109464  35.293611  53.732697  58.110591
# 2017-12-31   98.541172  186.857813  37.361764  60.053506  42.412631
# 2018-12-31   94.835368  177.347138  34.840652  65.359015  58.809759
# 2019-12-31   85.357119  166.545542  29.093518  67.899894  58.005923
# 2020-12-31   61.897335  132.359323  16.655137  32.143279  30.649208
#
#                   NH3         CO        SO2         O3   Benzene    Toluene  \
# Date
# 2015-12-31  23.756178  10.129609  24.198658  45.023904  4.224499  12.820125
# 2016-12-31  21.371237  10.654428  30.622718  55.000257  4.030047  14.502250
# 2017-12-31  22.443272  12.209647  42.466202  43.010833  4.442941  16.652489
# 2018-12-31  21.198562  17.295461  41.723221  42.007880  5.849202  30.902001
# 2019-12-31  18.200603  13.720343  43.171435  42.693161  4.525312  35.801748
# 2020-12-31  17.053388   4.940464  27.038499  42.117600  3.132726  25.767954
#
#               Xylene         AQI
# Date
# 2015-12-31  3.106301  323.713068
# 2016-12-31  2.075255  353.998770
# 2017-12-31  3.027223  364.539424
# 2018-12-31  3.540311  433.846553
# 2019-12-31  3.167352  373.084381
# 2020-12-31  1.451876  215.887597

# %%
saqi = pd.read_csv("Data/saqi.csv")
saqi["Date"] = pd.to_datetime(saqi.Date)
saqi['Date'] = saqi['Date'].dt.strftime('%Y')
saqi.rename(columns = {'Date':'year'}, inplace = True)

saqi
# Out:
#    year       PM2.5        PM10         NO        NO2        NOx        NH3  \
# 0  2015   96.957722  172.314459  23.977015  38.897006  58.671256  23.756178
# 1  2016  102.264513  186.109464  35.293611  53.732697  58.110591  21.371237
# 2  2017   98.541172  186.857813  37.361764  60.053506  42.412631  22.443272
# 3  2018   94.835368  177.347138  34.840652  65.359015  58.809759  21.198562
# 4  2019   85.357119  166.545543  29.093518  67.899894  58.005923  18.200603
# 5  2020   61.897335  132.359323  16.655137  32.143279  30.649208  17.053388
#
#           CO        SO2         O3   Benzene    Toluene    Xylene         AQI  \
# 0  10.129609  24.198658  45.023904  4.224499  12.820125  3.106301  323.713068
# 1  10.654428  30.622718  55.000257  4.030047  14.502250  2.075255  353.998770
# 2  12.209647  42.466202  43.010833  4.442941  16.652489  3.027223  364.539424
# 3  17.295461  41.723221  42.007880  5.849202  30.902001  3.540311  433.846553
# 4  13.720343  43.171435  42.693161  4.525312  35.801748  3.167352  373.084381
# 5   4.940464  27.038499  42.117600  3.132726  25.767954  1.451876  215.887597
#
#   AQI_Bucket
# 0     Severe
# 1     Severe
# 2     Severe
# 3     Severe
# 4     Severe
# 5  Very Poor

# %%
ahmd = pd.read_excel("Data/Ahmd.xlsx")
ahmd
# Out:
#    year  sales in millions
# 0  2015               3.42
# 1  2016               3.66
# 2  2017               3.91
# 3  2018               4.13
# 4  2019               4.26
# 5  2020               4.33

# %%
delhi = pd.read_excel("Data/Delhi.xlsx")
delhi
# Out:
#    year  sales in millions
# 0  2015               8.83
# 1  2016               9.70
# 2  2017              10.38
# 3  2018              10.99
# 4  2019              11.39
# 5  2020              11.89

# %%
aadd = pd.merge(ahmd, delhi, how='inner', on = 'year')
aadd['Licensed vehicle'] = aadd['sales in millions_x'] + aadd['sales in millions_y']
aadd.rename(columns = {'sales in millions_x':'Ahmedabad', 'sales in millions_y':'Delhi'}, inplace = True)

aadd
# Out:
#    year  Ahmedabad  Delhi  Licensed vehicle
# 0  2015       3.42   8.83             12.25
# 1  2016       3.66   9.70             13.36
# 2  2017       3.91  10.38             14.29
# 3  2018       4.13  10.99             15.12
# 4  2019       4.26  11.39             15.65
# 5  2020       4.33  11.89             16.22

# %%
maadd = pd.concat([saqi, aadd], axis=1, join="inner")
maadd
# Out:
#    year       PM2.5        PM10         NO        NO2        NOx        NH3  \
# 0  2015   96.957722  172.314459  23.977015  38.897006  58.671256  23.756178
# 1  2016  102.264513  186.109464  35.293611  53.732697  58.110591  21.371237
# 2  2017   98.541172  186.857813  37.361764  60.053506  42.412631  22.443272
# 3  2018   94.835368  177.347138  34.840652  65.359015  58.809759  21.198562
# 4  2019   85.357119  166.545543  29.093518  67.899894  58.005923  18.200603
# 5  2020   61.897335  132.359323  16.655137  32.143279  30.649208  17.053388
#
#           CO        SO2         O3   Benzene    Toluene    Xylene         AQI  \
# 0  10.129609  24.198658  45.023904  4.224499  12.820125  3.106301  323.713068
# 1  10.654428  30.622718  55.000257  4.030047  14.502250  2.075255  353.998770
# 2  12.209647  42.466202  43.010833  4.442941  16.652489  3.027223  364.539424
# 3  17.295461  41.723221  42.007880  5.849202  30.902001  3.540311  433.846553
# 4  13.720343  43.171435  42.693161  4.525312  35.801748  3.167352  373.084381
# 5   4.940464  27.038499  42.117600  3.132726  25.767954  1.451876  215.887597
#
#   AQI_Bucket  year  Ahmedabad  Delhi  Licensed vehicle
# 0     Severe  2015       3.42   8.83             12.25
# 1     Severe  2016       3.66   9.70             13.36
# 2     Severe  2017       3.91  10.38             14.29
# 3     Severe  2018       4.13  10.99             15.12
# 4     Severe  2019       4.26  11.39             15.65
# 5  Very Poor  2020       4.33  11.89             16.22

# %%
maadd = maadd.loc[:,~maadd.columns.duplicated()].copy()
maadd
# Out:
#    year       PM2.5        PM10         NO        NO2        NOx        NH3  \
# 0  2015   96.957722  172.314459  23.977015  38.897006  58.671256  23.756178
# 1  2016  102.264513  186.109464  35.293611  53.732697  58.110591  21.371237
# 2  2017   98.541172  186.857813  37.361764  60.053506  42.412631  22.443272
# 3  2018   94.835368  177.347138  34.840652  65.359015  58.809759  21.198562
# 4  2019   85.357119  166.545543  29.093518  67.899894  58.005923  18.200603
# 5  2020   61.897335  132.359323  16.655137  32.143279  30.649208  17.053388
#
#           CO        SO2         O3   Benzene    Toluene    Xylene         AQI  \
# 0  10.129609  24.198658  45.023904  4.224499  12.820125  3.106301  323.713068
# 1  10.654428  30.622718  55.000257  4.030047  14.502250  2.075255  353.998770
# 2  12.209647  42.466202  43.010833  4.442941  16.652489  3.027223  364.539424
# 3  17.295461  41.723221  42.007880  5.849202  30.902001  3.540311  433.846553
# 4  13.720343  43.171435  42.693161  4.525312  35.801748  3.167352  373.084381
# 5   4.940464  27.038499  42.117600  3.132726  25.767954  1.451876  215.887597
#
#   AQI_Bucket  Ahmedabad  Delhi  Licensed vehicle
# 0     Severe       3.42   8.83             12.25
# 1     Severe       3.66   9.70             13.36
# 2     Severe       3.91  10.38             14.29
# 3     Severe       4.13  10.99             15.12
# 4     Severe       4.26  11.39             15.65
# 5  Very Poor       4.33  11.89             16.22

# %%
maadd["Growth"] = pd.DataFrame(maadd["Licensed vehicle"].pct_change())
maadd = maadd.fillna(0)

# %%
maadd
# Out:
#    year       PM2.5        PM10         NO        NO2        NOx        NH3  \
# 0  2015   96.957722  172.314459  23.977015  38.897006  58.671256  23.756178
# 1  2016  102.264513  186.109464  35.293611  53.732697  58.110591  21.371237
# 2  2017   98.541172  186.857813  37.361764  60.053506  42.412631  22.443272
# 3  2018   94.835368  177.347138  34.840652  65.359015  58.809759  21.198562
# 4  2019   85.357119  166.545543  29.093518  67.899894  58.005923  18.200603
# 5  2020   61.897335  132.359323  16.655137  32.143279  30.649208  17.053388
#
#           CO        SO2         O3   Benzene    Toluene    Xylene         AQI  \
# 0  10.129609  24.198658  45.023904  4.224499  12.820125  3.106301  323.713068
# 1  10.654428  30.622718  55.000257  4.030047  14.502250  2.075255  353.998770
# 2  12.209647  42.466202  43.010833  4.442941  16.652489  3.027223  364.539424
# 3  17.295461  41.723221  42.007880  5.849202  30.902001  3.540311  433.846553
# 4  13.720343  43.171435  42.693161  4.525312  35.801748  3.167352  373.084381
# 5   4.940464  27.038499  42.117600  3.132726  25.767954  1.451876  215.887597
#
#   AQI_Bucket  Ahmedabad  Delhi  Licensed vehicle    Growth
# 0     Severe       3.42   8.83             12.25  0.000000
# 1     Severe       3.66   9.70             13.36  0.090612
# 2     Severe       3.91  10.38             14.29  0.069611
# 3     Severe       4.13  10.99             15.12  0.058083
# 4     Severe       4.26  11.39             15.65  0.035053
# 5  Very Poor       4.33  11.89             16.22  0.036422

# %% [markdown]
# # EDA

# %% [markdown]
# ### Typically a vehicle emits CO, NOx, NO, NO2, PM10, PM2.5, SO2, Benzene& O3
#
# ### Hence, lets find if with growing car sales does these emission fairly increases or not

# %%
dv = ["Licensed vehicle", "Growth"]

palette = sns.cubehelix_palette(light = 0.9, n_colors = 6)

for d in dv:
    sns.barplot(x = "year", y = d, data = maadd, palette=palette)
    plt.savefig("Images/graphs/{}.png".format(d), dpi = 1200, facecolor='w')
    plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize = (20, 20))

palette = "ch:0.150"

sns.barplot(x = "year", y="CO", data = maadd, hue = "AQI_Bucket", ax = ax[0][0], palette=palette)
sns.barplot(x = "year", y="NOx", data = maadd, hue = "AQI_Bucket", ax = ax[0][1], palette=palette)
sns.barplot(x = "year", y="NO", data = maadd, hue = "AQI_Bucket", ax = ax[0][2], palette=palette)
sns.barplot(x = "year", y="NO2", data = maadd, hue = "AQI_Bucket", ax = ax[1][0], palette=palette)
sns.barplot(x = "year", y="PM10", data = maadd, hue = "AQI_Bucket", ax = ax[1][1], palette=palette)
sns.barplot(x = "year", y="PM2.5", data = maadd, hue = "AQI_Bucket", ax = ax[1][2], palette=palette)
sns.barplot(x = "year", y="O3", data = maadd, hue = "AQI_Bucket", ax = ax[2][0], palette=palette)
sns.barplot(x = "year", y="SO2", data = maadd, hue = "AQI_Bucket", ax = ax[2][1], palette=palette)
sns.barplot(x = "year", y="Benzene", data = maadd, hue = "AQI_Bucket", ax = ax[2][2], palette=palette)

plt.title("Bar plots to get each gas's presence in each year")

plt.savefig("Images/graphs/Second.png", dpi=500, facecolor='w')

plt.show()

# %%
maadddesc = maadd.describe()
maaddMean = maadddesc.loc["mean"]
maaddMean = maaddMean.drop(["NH3", "Toluene", "Xylene", "AQI", "Ahmedabad", "Delhi", "vehicle sales", "Growth"], axis=0, inplace=False)
maaddMean
# Out:
# PM2.5       89.975538
# PM10       170.255623
# NO          29.536949
# NO2         53.014233
# NOx         51.109894
# CO          11.491659
# SO2         34.870122
# O3          44.975606
# Benzene      4.367455
# Name: mean, dtype: float64

# %%
plt.figure(figsize = (10, 6))
plt.style.use("seaborn")
fig, ax = plt.subplots(figsize = (10, 6), dpi = 100)
explode = [0.1, 0, 0.1, 0, 0, 0.2, 0.1, 0, 0.1]
maaddMean.plot.pie(autopct='%1.1f%%', explode = explode)
plt.savefig("Images/graphs/pie.png", dpi = 1200, facecolor='w')
plt.show()

# %%
iv = ["CO", "NOx", "NO", "NO2", "PM10", "PM2.5", "O3", "SO2", "Benzene"]
corrdata = pd.DataFrame()
for i in iv:
    print("Correlation coefficient of {} is".format(i), maadd['Licensed vehicle'].corr(maadd[i]))
    v = maadd['Licensed vehicle'].corr(maadd[i])    
    df2 = {'Gas Name': i, 'Corr Coef': v}
    corrdata = corrdata.append(df2, ignore_index = True)
# Out:
# Correlation coefficient of CO is -0.040459262062746054
# Correlation coefficient of NOx is -0.5159700020265257
# Correlation coefficient of NO is -0.25345853614985264
# Correlation coefficient of NO2 is 0.16940145873399623
# Correlation coefficient of PM10 is -0.6084733661667626
# Correlation coefficient of PM2.5 is -0.7419348522816874
# Correlation coefficient of O3 is -0.5478658537286529
# Correlation coefficient of SO2 is 0.4328519784406027
# Correlation coefficient of Benzene is -0.050789885660338034

# %%
corrdata
# Out:
#   Gas Name  Corr Coef
# 0       CO  -0.040459
# 1      NOx  -0.515970
# 2       NO  -0.253459
# 3      NO2   0.169401
# 4     PM10  -0.608473
# 5    PM2.5  -0.741935
# 6       O3  -0.547866
# 7      SO2   0.432852
# 8  Benzene  -0.050790

# %%
palette = sns.cubehelix_palette(light = 0.9, n_colors = 6)
sns.barplot(data=corrdata, x="Gas Name", y="Corr Coef", palette=palette)
plt.savefig("Images/graphs/corrcoef.png", dpi = 1200, facecolor='w')
plt.show()

# %% [markdown]
# # End
